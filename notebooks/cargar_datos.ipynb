# %%
import pandas as pd
import os

# Definir la ruta del archivo
RAW_DATA_PATH = "C:/Users/Lucas/Proyectos/ProyectoIntegrador/data/raw/Base_de_datos.csv"

# Cargar el dataset no productivo
df = pd.read_csv(RAW_DATA_PATH)

# Mostrar dimensiones y primeras observaciones para verificación de carga
print(f"Dimensiones del dataset: {df.shape[0]} filas, {df.shape[1]} columnas")
df.head()
# Out:
# Dimensiones del dataset: 10763 filas, 23 columnas
#    tipo_credito  fecha_prestamo  capital_prestado  plazo_meses  edad_cliente  \
# 0             7  12/21/24 11:31           3692160           10            42
# 1             4    4/22/25 9:47            840000            6            60
# 2             9    1/8/26 12:22           5974028           10            36
# 3             4    8/4/25 12:04           1671240            6            48
# 4             9   4/26/25 11:24           2781636           11            44
#
#     tipo_laboral  salario_cliente  total_otros_prestamos  cuota_pactada  \
# 0  Independiente          8000000                2500000         341296
# 1       Empleado          3000000                2000000         124876
# 2  Independiente          4036000                 829000         529554
# 3       Empleado          1524547                 498000         252420
# 4       Empleado          5000000                4000000         217037
#
# ...
